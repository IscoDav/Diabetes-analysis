# %% [markdown]
# # Diabetes Classification
# This project and its Classification Model aims to identify whether patients have <b>DIABETES</b> or not by analyzing results of their other medical analyses and features.
#
# ## What is Diabetes
#
# Diabetes is a condition in which the body cannot use the sugars and starches (carbohydrates) it takes in as food to make energy. The body either makes no insulin or too little insulin or cannot use the insulin it makes to change those sugars and starches into energy. As a result, extra sugar builds up in the blood.(2020, U.S. Department of Health & Human Services)
#
# The three most common types of diabetes are:
#
# <b>Type 1 :</b> In type 1 diabetes, your immune system mistakenly treats the beta cells in your pancreas that make insulin as foreign invaders and destroys them. This can happen over a few weeks, months, or years.(2022, American Diabetes Association)
#
# <b>Type 2 :</b> In type 2 diabetes, your body does not use insulin properly. This is called insulin resistance. At first, the beta cells make extra insulin to make up for it. But, over time your pancreas can't make enough insulin to keep your blood sugar at normal levels. Type 2 diabetes develops most often in middle-aged and older adults but can appear in young people.(2022, American Diabetes Association)
#
# <b>Gestational :</b> Gestational diabetes is diabetes that develops during pregnancy. For most women, blood sugar levels will return to normal after giving birth. (2022, American Diabetes Association)
#
#
# ### Pregnancies
# Normally, various hormones work to keep your blood sugar levels in check. But during pregnancy, hormone levels change, making it harder for your body to process blood sugar efficiently. This makes your blood sugar rise.(2022, Mayo Foundation for Medical Education and Research (MFMER))
#
# ### Glucose
# Diabetes is a problem with your body that causes blood sugar (also called blood glucose) levels to rise higher than normal. This is also called hyperglycemia.(2022, American Diabetes Association)
#
# When you eat, your body breaks food down into sugar and sends it into the blood. Insulin then helps move the sugar from the blood into your cells. When sugar enters your cells, it is either used as fuel for energy right away or stored for later use. In a person with diabetes, there is a problem with insulin.(2022, American Diabetes Association)
#
# <b>Fasting Blood Sugar Test</b>
# This measures your blood sugar after an overnight fast (not eating). A fasting blood sugar level of 99 mg/dL or lower is normal, 100 to 125 mg/dL indicates you have prediabetes, and 126 mg/dL or higher indicates you have diabetes.(2022, Centers for Disease Control and Prevention)
#
# ### Blood Pressure
# Blood pressure is the pressure your heart uses to push blood through your blood vessels and around your body.
#
# There are two numbers used to describe blood pressure and it’s measured in millimetres of mercury (mmHg). It’s written like this: 130/80mmHg. And you’ll hear your doctor say '130 over 80'.
#
# The first number is the systolic pressure. This is the most amount of pressure your heart uses when beating to push the blood around your body.
# The second number is the diastolic pressure. This is the least amount of pressure your heart uses when it is relaxed between beats.
#
# **Blood pressure should be below 140/80mmHg for people with diabetes or below 130/80mmHg if you have kidney or eye disease or any condition that affects blood vessels and blood supply to the brain** (2022, The British Diabetic)
#
# ### Skin Thickness
# **In fact, skin problems are sometimes the first sign that a person has diabetes.**
# The average Skin Thicknes for patience who has diabetes is 29.15 +-
#
# ### Insulin
# Insulin helps control blood glucose levels by signaling the liver and muscle and fat cells to take in glucose from the blood. Insulin therefore helps cells to take in glucose to be used for energy.(2022, The British Diabetic)
#
#
# ### BMI
#
# BMI (Body Mass Index) is a number calculated by dividing a person's weight in kilograms by his or her height in meters squared. BMI is a useful tool used in determining the degree of an individual's excess weight.
#
# Being overweight **(BMI of 25-29.9)**, or affected by obesity **(BMI of 30-39.9)** or morbid obesity **(BMI of 40 or greater)**, greatly increases your risk of developing type 2 diabetes. The more excess weight you have, the more resistant your muscle and tissue cells become to your own insulin hormone. More than 90 percent of people with type 2 diabetes are overweight or affected by a degree of obesity. (2011, Obesity Action Coalition (OAC))
#
# ### Diabetes Pedugree Function
# Diabetes pedigree function (a function which scores likelihood of diabetes based on family history)
#
# ### Age
# Age is a big risk factor for type 2. The older you are, the more likely you are to have it. That also holds true for preteens and teenagers, whose diabetes rates have climbed sharply in recent years.(2020, WebMD, LLC)

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Reading the Dataset

# %%
data = pd.read_csv('diabetes.csv')
df = data.copy()

# %% [markdown]
# ## Part 1 : Understanding the dataset

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail() # as you can see in column Insulin some values are 0. So, we need to feel them with that columns means
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 752                     0.223   25        0
# 753                     0.222   26        1
# 754                     0.443   45        1
# 755                     1.057   37        1
# 756                     0.391   39        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               757 non-null    int64
#  1   Glucose                   757 non-null    int64
#  2   BloodPressure             757 non-null    int64
#  3   SkinThickness             757 non-null    int64
#  4   Insulin                   757 non-null    int64
#  5   BMI                       757 non-null    float64
#  6   DiabetesPedigreeFunction  757 non-null    float64
#  7   Age                       757 non-null    int64
#  8   Outcome                   757 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 53.4 KB

# %%
df.shape
# Out:
# (757, 9)

# %% [markdown]
# ## 1.1 -  Checking for null values

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## 1.2 - Checkin for how many 0 values Insulin column has

# %%
df['Insulin'].value_counts() # 374 rows have 0 values so these need to be replaced with its meand/median
# Out:
# 0      366
# 105     11
# 140      9
# 130      9
# 120      8
#       ...
# 29       1
# 32       1
# 159      1
# 14       1
# 846      1
# Name: Insulin, Length: 184, dtype: int64

# %% [markdown]
# ## 1.3 - Replacing 0 values the colums mean

# %%
in_mean = round(df['Insulin'].mean(),1) # getting mean value of insulin
df.Insulin = df.Insulin.replace({0:in_mean})  # replacing zero values to column mean 
df['Insulin'].value_counts()
# Out:
# 80     366
# 105     11
# 140      9
# 130      9
# 120      8
#       ...
# 146      1
# 142      1
# 129      1
# 128      1
# 846      1
# Name: Insulin, Length: 184, dtype: int64

# %% [markdown]
# ## 1.4 - Changing data type of the insulin to as before to integer

# %%
df['Insulin'] = df['Insulin'].astype('int64')
df['Insulin']
# Out:
# 0       80
# 1       80
# 2       80
# 3       94
# 4      168
#       ...
# 752     80
# 753    510
# 754     80
# 755    110
# 756     80
# Name: Insulin, Length: 757, dtype: int64

# %% [markdown]
# ## 1.5 - Checking the data distribution of the columns

# %%
sns.pairplot(df, hue='Outcome')

# %% [markdown]
# ## 1.6 - Checking the correlation of the colums to each other

# %%
corr_matrix = df.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')

# Here we can see that some of the colums have very close correlations to the target columns such as 
# Pregnancies,Glucose,SkinThickness,Insulin,BMI and Age
# Out:
# <style  type="text/css" >
# #T_6b116_row0_col0,#T_6b116_row1_col1,#T_6b116_row2_col2,#T_6b116_row3_col3,#T_6b116_row4_col4,#T_6b116_row5_col5,#T_6b116_row6_col6,#T_6b116_row7_col7,#T_6b116_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_6b116_row0_col1,#T_6b116_row2_col6{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_6b116_row0_col2{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_6b116_row0_col3,#T_6b116_row3_col8,#T_6b116_row8_col2{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_6b116_row0_col4,#T_6b116_row0_col5,#T_6b116_row0_col6,#T_6b116_row2_col8,#T_6b116_row3_col0,#T_6b116_row3_col1,#T_6b116_row3_col7,#T_6b116_row6_col2,#T_6b116_row7_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_6b116_row0_col7{
#             background-color:  #f1cdba;
#             color:  #000000;
#         }#T_6b116_row0_col8,#T_6b116_row3_col2,#T_6b116_row6_col4,#T_6b116_row8_col3{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_6b116_row1_col0,#T_6b116_row8_col4{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_6b116_row1_col2{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_6b116_row1_col3{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_6b116_row1_col4{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_6b116_row1_col5,#T_6b116_row7_col2,#T_6b116_row8_col6{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_6b116_row1_col6,#T_6b116_row5_col1,#T_6b116_row5_col6{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_6b116_row1_col7{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_6b116_row1_col8,#T_6b116_row8_col1{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_6b116_row2_col0,#T_6b116_row3_col6,#T_6b116_row5_col4,#T_6b116_row7_col1{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_6b116_row2_col1{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_6b116_row2_col3{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_6b116_row2_col4{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_6b116_row2_col5,#T_6b116_row6_col3{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_6b116_row2_col7{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_6b116_row3_col4{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_6b116_row3_col5{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_6b116_row4_col0{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_6b116_row4_col1{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_6b116_row4_col2{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_6b116_row4_col3{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_6b116_row4_col5,#T_6b116_row7_col8{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_6b116_row4_col6{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_6b116_row4_col7{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_6b116_row4_col8,#T_6b116_row6_col5{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_6b116_row5_col0{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_6b116_row5_col2{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_6b116_row5_col3{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_6b116_row5_col7{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_6b116_row5_col8{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_6b116_row6_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_6b116_row6_col1{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_6b116_row6_col7{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_6b116_row6_col8{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_6b116_row7_col0{
#             background-color:  #efcebd;
#             color:  #000000;
#         }#T_6b116_row7_col4{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_6b116_row7_col5{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_6b116_row7_col6{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_6b116_row8_col0{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_6b116_row8_col5{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_6b116_row8_col7{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }</style><table id="T_6b116_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pregnancies</th>        <th class="col_heading level0 col1" >Glucose</th>        <th class="col_heading level0 col2" >BloodPressure</th>        <th class="col_heading level0 col3" >SkinThickness</th>        <th class="col_heading level0 col4" >Insulin</th>        <th class="col_heading level0 col5" >BMI</th>        <th class="col_heading level0 col6" >DiabetesPedigreeFunction</th>        <th class="col_heading level0 col7" >Age</th>        <th class="col_heading level0 col8" >Outcome</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6b116_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#                         <td id="T_6b116_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_6b116_row0_col1" class="data row0 col1" >0.128080</td>
#                         <td id="T_6b116_row0_col2" class="data row0 col2" >0.140760</td>
#                         <td id="T_6b116_row0_col3" class="data row0 col3" >-0.088439</td>
#                         <td id="T_6b116_row0_col4" class="data row0 col4" >-0.020719</td>
#                         <td id="T_6b116_row0_col5" class="data row0 col5" >0.018153</td>
#                         <td id="T_6b116_row0_col6" class="data row0 col6" >-0.030967</td>
#                         <td id="T_6b116_row0_col7" class="data row0 col7" >0.547527</td>
#                         <td id="T_6b116_row0_col8" class="data row0 col8" >0.225947</td>
#             </tr>
#             <tr>
#                         <th id="T_6b116_level0_row1" class="row_heading level0 row1" >Glucose</th>
#                         <td id="T_6b116_row1_col0" class="data row1 col0" >0.128080</td>
#                         <td id="T_6b116_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_6b116_row1_col2" class="data row1 col2" >0.149405</td>
#                         <td id="T_6b116_row1_col3" class="data row1 col3" >0.061059</td>
#                         <td id="T_6b116_row1_col4" class="data row1 col4" >0.394379</td>
#                         <td id="T_6b116_row1_col5" class="data row1 col5" >0.217190</td>
#                         <td id="T_6b116_row1_col6" class="data row1 col6" >0.139088</td>
#                         <td id="T_6b116_row1_col7" class="data row1 col7" >0.258372</td>
#                         <td id="T_6b116_row1_col8" class="data row1 col8" >0.462368</td>
#             </tr>
#             <tr>
#                         <th id="T_6b116_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#                         <td id="T_6b116_row2_col0" class="data row2 col0

# %% [markdown]
# ## 1.7 - Dropping ALL duplicate values in case

# %%
df.drop_duplicates(keep = False, inplace = True)

# %% [markdown]
# ## 1.8 -  Visualizing the target variable to check its balance

# %%
g = sns.countplot(x = df['Outcome'])
plt.show()

# Target data is quite normal for now but if the result of 
#the model need to be upgraded so we gonna balance target

# %% [markdown]
# ## 1.9 - Balancing the target data
# Tried train the model without balancing the target but the results were not satisfying

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler 
from collections import Counter 


y = df['Outcome']
X = df.drop(['Outcome'],axis=1)

# instantiating the random over sampLer 
ros = RandomOverSampler()
 # resampLing X, y x_ros, y_
X_ros, y_ros = ros.fit_resample(X, y) 
# new class distribution
print(Counter(y_ros))
# Out:
# Counter({1: 493, 0: 493})

# %% [markdown]
# # Part - 2 Training dataset to different Classification Models

# %% [markdown]
# ## 2.1 - Splitting data to train and test

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X_ros,y_ros, test_size = 0.20, random_state = 101)

# shapes must be the same 
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (788, 8) (198, 8)
# (788,) (198,)

# %% [markdown]
# ## 2.2 - KNeighborsClassifier

# %%
# Scaling the data and target for KNN to get better result. Using MinMax scaling method for this.

from sklearn.preprocessing import MinMaxScaler

scaling = MinMaxScaler()
X_train_minmax = scaling.fit_transform(X_train)
X_test_minmax = scaling.fit_transform(X_test)

# %%
# Training scaled test and train dataset

from sklearn.neighbors import KNeighborsClassifier
# importing needed libraries for evaluating models 
from sklearn.metrics import classification_report,confusion_matrix 
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train_minmax, y_train)
knn_pred = knn.predict(X_test_minmax)

# Evaluating Model
print(accuracy_score(y_test, knn_pred))
print(confusion_matrix(y_test, knn_pred))
print(classification_report(y_test, knn_pred))
# Out:
# 0.6868686868686869
# [[64 37]
#  [25 72]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.63      0.67       101
#            1       0.66      0.74      0.70        97
#
#     accuracy                           0.69       198
#    macro avg       0.69      0.69      0.69       198
# weighted avg       0.69      0.69      0.69       198

# %% [markdown]
# ## 2.3 - DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
Dtree_pred = dt.predict(X_test)




print(accuracy_score(y_test, Dtree_pred))
print(confusion_matrix(y_test, Dtree_pred))
print(classification_report(y_test, Dtree_pred))
# Out:
# 0.8181818181818182
# [[79 22]
#  [14 83]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81       101
#            1       0.79      0.86      0.82        97
#
#     accuracy                           0.82       198
#    macro avg       0.82      0.82      0.82       198
# weighted avg       0.82      0.82      0.82       198

# %% [markdown]
# ## 2.4 - Support Vector Machine

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

model = SVC()
model.fit(X_train,y_train)
svm_pred = model.predict(X_test)

# Evaluating Model
print(accuracy_score(y_test, svm_pred).round(3))
print(confusion_matrix(y_test, svm_pred))
print(classification_report(y_test, svm_pred))
# Out:
# 0.747
# [[80 21]
#  [29 68]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.79      0.76       101
#            1       0.76      0.70      0.73        97
#
#     accuracy                           0.75       198
#    macro avg       0.75      0.75      0.75       198
# weighted avg       0.75      0.75      0.75       198

# %% [markdown]
# ## 2.5 - Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=14, random_state=101)
clf.fit(X_train, y_train)
rf = clf.predict(X_test)

# Evaluating Model
print(accuracy_score(y_test, rf))
print(confusion_matrix(y_test, rf))
print(classification_report(y_test, rf))
# Out:
# 0.8333333333333334
# [[82 19]
#  [14 83]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       101
#            1       0.81      0.86      0.83        97
#
#     accuracy                           0.83       198
#    macro avg       0.83      0.83      0.83       198
# weighted avg       0.83      0.83      0.83       198

# %%
# trying with cross validation
from sklearn.model_selection import cross_val_score

score = cross_val_score(clf, X_train, y_train, cv=100)
score.mean()
# Out:
# 0.8551785714285716

# %% [markdown]
# ## 2.6 - GradientBoostingRegressor

# %%
## GradientBoostingRegressor 
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
gb_pred = gb.predict(X_test)

# Evaluating Model
print(accuracy_score(y_test, gb_pred))
print(confusion_matrix(y_test, gb_pred))
print(classification_report(y_test, gb_pred))
# Out:
# 0.797979797979798
# [[78 23]
#  [17 80]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.80       101
#            1       0.78      0.82      0.80        97
#
#     accuracy                           0.80       198
#    macro avg       0.80      0.80      0.80       198
# weighted avg       0.80      0.80      0.80       198

# %%
from sklearn.ensemble import ExtraTreesClassifier
ext = ExtraTreesClassifier()
ext.fit(X_train, y_train)
ET_pred = ext.predict(X_test)

# Evaluating Model
print(accuracy_score(y_test, ET_pred))
print(confusion_matrix(y_test, ET_pred))
print(classification_report(y_test, ET_pred))
# Out:
# 0.8282828282828283
# [[88 13]
#  [21 76]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       101
#            1       0.85      0.78      0.82        97
#
#     accuracy                           0.83       198
#    macro avg       0.83      0.83      0.83       198
# weighted avg       0.83      0.83      0.83       198

# %% [markdown]
# # Part 3 - Choosing right model
# <b>As we can see the results of the models, random forest, decision tree and gradient booster models are showing quite good result for the beginning. We can take these two models(Random Fores and Gradient Booster) for testing with new data</b>

# %% [markdown]
# ## 3.1 - Reading new dataset

# %%
new_data = pd.read_csv('test.csv')
df2 = new_data.copy()

# %%
df2.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            0      123             72              0        0  36.3
# 1            1      106             76              0        0  37.5
# 2            6      190             92              0        0  35.5
# 3            2       88             58             26       16  28.4
# 4            9      170             74             31        0  44.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.258   52        1
# 1                     0.197   26        0
# 2                     0.278   66        1
# 3                     0.766   22        0
# 4                     0.403   43        1

# %%
df2.shape
# Out:
# (11, 9)

# %% [markdown]
# ## 3.2 - Data preparation

# %%
df2['Insulin'].value_counts() # 8 rows have 0 values so these need to be replaced with its meand/median
# Out:
# 0      8
# 180    1
# 112    1
# 16     1
# Name: Insulin, dtype: int64

# %%
# we gonna put mean of the insulin that we taken from first data set to not vary
df2['Insulin'] = df2['Insulin'].replace({0:80})  # replacing zero values to column mean 
df2['Insulin'].value_counts()
# Out:
# 80     8
# 180    1
# 112    1
# 16     1
# Name: Insulin, dtype: int64

# %% [markdown]
# ## 3.3 - Splitting dataset to target and test

# %%
new_y = df2['Outcome']
new_X = df2.drop(["Outcome"], axis=1)

# %% [markdown]
# ## 3.4 - Random Forest

# %%
new_rf = clf.predict(new_X)

# Evaluating Model
print(accuracy_score(new_y, new_rf))
print(confusion_matrix(new_y, new_rf))
print(classification_report(new_y, new_rf))
# Out:
# 1.0
# [[7 0]
#  [0 4]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        11
#    macro avg       1.00      1.00      1.00        11
# weighted avg       1.00      1.00      1.00        11

# %% [markdown]
# ## 3.5 - Gradient Booster

# %%
new_gb = gb.predict(new_X)

# Evaluating Model
print(accuracy_score(new_y, new_gb))
print(confusion_matrix(new_y, new_gb))
print(classification_report(new_y, new_gb))
# Out:
# 1.0
# [[7 0]
#  [0 4]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        11
#    macro avg       1.00      1.00      1.00        11
# weighted avg       1.00      1.00      1.00        11

# %% [markdown]
# ## Conclusion
# As you can see we have tried various models and from my point of view Random forest Classifier model has the best prediction for diabetes for now. But I am going to improve and update these models later on.
